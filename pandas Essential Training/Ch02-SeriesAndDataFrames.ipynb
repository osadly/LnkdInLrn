# %%
import pandas as pd

# %%
oo = pd.read_csv("./DATA/Kgl120YrsOlmpcsHstrAthlts&Rslts/athlete_events.csv")
oo.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
oo
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
oo2 = pd.read_csv("./DATA/Kgl120YrsOlmpcsHstrAthlts&Rslts/noc_regions.csv")
oo2.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
oo2
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
oo.City
# Out:
# 0              Barcelona
# 1                 London
# 2              Antwerpen
# 3                  Paris
# 4                Calgary
#                ...
# 271111         Innsbruck
# 271112             Sochi
# 271113             Sochi
# 271114            Nagano
# 271115    Salt Lake City
# Name: City, Length: 271116, dtype: object

# %%
oo['City']
# Out:
# 0              Barcelona
# 1                 London
# 2              Antwerpen
# 3                  Paris
# 4                Calgary
#                ...
# 271111         Innsbruck
# 271112             Sochi
# 271113             Sochi
# 271114            Nagano
# 271115    Salt Lake City
# Name: City, Length: 271116, dtype: object

# %%
oo2[['NOC','region']]
# Out:
#      NOC       region
# 0    AFG  Afghanistan
# 1    AHO      Curacao
# 2    ALB      Albania
# 3    ALG      Algeria
# 4    AND      Andorra
# ..   ...          ...
# 225  YEM        Yemen
# 226  YMD        Yemen
# 227  YUG       Serbia
# 228  ZAM       Zambia
# 229  ZIM     Zimbabwe
#
# [230 rows x 2 columns]

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo2[['NOC','region']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo2.NOC)
# Out:
# pandas.core.series.Series

# %%
oo
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# ### Ch 02 Challenge & Solution

# %%
import pandas as pd

# %%
noc_regions = pd.read_csv(r"C:\Users\samwa\OneDrive - Metrolinx\!P\LnkdN\AI & ML\pandas Essential Training\DATA\Kgl120YrsOlmpcsHstrAthlts&Rslts\noc_regions.csv")
noc_regions.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
noc_regions
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
noc_regions['NOC']
# Out:
# 0      AFG
# 1      AHO
# 2      ALB
# 3      ALG
# 4      AND
#       ...
# 225    YEM
# 226    YMD
# 227    YUG
# 228    ZAM
# 229    ZIM
# Name: NOC, Length: 230, dtype: object

# %%
noc_regions.NOC
# Out:
# 0      AFG
# 1      AHO
# 2      ALB
# 3      ALG
# 4      AND
#       ...
# 225    YEM
# 226    YMD
# 227    YUG
# 228    ZAM
# 229    ZIM
# Name: NOC, Length: 230, dtype: object

# %%
type(noc_regions['NOC'])
# Out:
# pandas.core.series.Series

# %%
type(noc_regions.NOC)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
type(noc_regions[['NOC','region']])
# Out:
# pandas.core.frame.DataFrame
