# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
athletesDF=pd.read_csv(r".\DATA\Kgl120YrsOlmpcsHstrAthlts&Rslts\athlete_events.csv")

# %%
athletesDF.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
athletesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
list(athletesDF.columns)
# Out:
# ['ID',
#  'Name',
#  'Sex',
#  'Age',
#  'Height',
#  'Weight',
#  'Team',
#  'NOC',
#  'Games',
#  'Year',
#  'Season',
#  'City',
#  'Sport',
#  'Event',
#  'Medal']

# %%
athletesDF.Name
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 2              Gunnar Nielsen Aaby
# 3             Edgar Lindenau Aabye
# 4         Christine Jacoba Aaftink
#                     ...
# 271111                  Andrzej ya
# 271112                    Piotr ya
# 271113                    Piotr ya
# 271114          Tomasz Ireneusz ya
# 271115          Tomasz Ireneusz ya
# Name: Name, Length: 271116, dtype: object

# %%
JesseOwensDF = athletesDF[(athletesDF.Name=='James Cleveland "Jesse" Owens') & (athletesDF.Medal!='NA')]

# %%
JesseOwensDF[['Event','City','Games','Sport']]
# Out:
#                                        Event    City        Games      Sport
# 179557            Athletics Men's 100 metres  Berlin  1936 Summer  Athletics
# 179558            Athletics Men's 200 metres  Berlin  1936 Summer  Athletics
# 179559  Athletics Men's 4 x 100 metres Relay  Berlin  1936 Summer  Athletics
# 179560             Athletics Men's Long Jump  Berlin  1936 Summer  Athletics

# %%
#Badminton Men's Singles
#Badminton Women's Singles

#SnglBdMntn = athletesDF[(athletesDF.Event.str.find('Badminton Men')!=-1) & (athletesDF.Event.str.find('Singles')!=-1)]
SnglBdMntn = athletesDF[(athletesDF.Event=='Badminton Men\'s Singles') & (athletesDF.Medal=='Gold')]

SnglBdMntnCntr = pd.DataFrame(SnglBdMntn.Team.value_counts())
SnglBdMntnCntr.head(1)
# Out:
#        count
# Team
# China      4

# %%
df=SnglBdMntn[SnglBdMntn.Team=='China']
df['Name'].sort_values()
# Out:
# 39337      Chen Long
# 108331    Ji Xinpeng
# 139311       Lin Dan
# 139312       Lin Dan
# Name: Name, dtype: object

# %%
lstMedals = ["Gold","Silver","Bronze"]
cntrsMedal=athletesDF[(athletesDF.Year>=1984) & (athletesDF.Year<=2004) &  (athletesDF.Medal.notna()) ]
cntrsMedal2=cntrsMedal[['Team','Medal']]
cntrsMedalCount=pd.DataFrame(cntrsMedal2.value_counts())
cntrsTotalMedals=cntrsMedalCount.groupby(['Team']).sum()
cntrsTotalMedals.sort_values(by="count",ascending=False)

#cntrsTotalMedals.sort_values(by)
#cntrsMedal=cntrsMedal.value_counts()
#cntrsMedal

#x=cntrsMedal2.groupby(['Team']).max()
#x
# Out:
#                count
# Team
# United States   1680
# Germany          722
# Australia        619
# Russia           597
# China            469
# ...              ...
# Burundi            1
# Uganda             1
# Djibouti           1
# Tunisia            1
# Ecuador            1
#
# [157 rows x 1 columns]

# %%
lstMedals = ["Gold","Silver","Bronze"]
cntrsMedal=athletesDF[(athletesDF.Year>=1984) & (athletesDF.Year<=2004) &  (athletesDF.Medal.notna()) ]
cntrsMedal
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 60          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 61          20         Kjetil Andr Aamodt   M  20.0   176.0    85.0
# 63          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 64          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# 67          20         Kjetil Andr Aamodt   M  22.0   176.0    85.0
# ...        ...                        ...  ..   ...     ...     ...
# 271032  135535  Claudia Antoinette Zwiers   F  22.0   181.0    78.0
# 271048  135545            Henk Jan Zwolle   M  27.0   197.0    93.0
# 271049  135545            Henk Jan Zwolle   M  31.0   197.0    93.0
# 271102  135563  Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563  Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
#                Team  NOC        Games  Year  Season         City  \
# 60           Norway  NOR  1992 Winter  1992  Winter  Albertville
# ...

# %%
athletesEgyptDF = athletesDF[(athletesDF.Team=='Egypt') & (athletesDF.Medal.notna())]
athletesEgyptDFYrMdl = athletesEgyptDF[['Year','Medal']]
athletesEgyptMdlsCntPerYearSrs = athletesEgyptDFYrMdl.value_counts()
athletesEgyptMdlsCntPerYearDF=pd.DataFrame(athletesEgyptMdlsCntPerYearSrs)
athletesEgyptMdlsCntPerYearDF.columns

#athletesEgyptMdlsCntPerYear_sortedDF = athletesEgyptMdlsCntPerYearDF.sort_values(by=['Medal','Year'],ascending=[True,True])
#athletesEgyptMdlsCntPerYear_sortedDF
# Out:
# Index(['count'], dtype='object')

# %%
athletesEgyptDF = athletesDF[(athletesDF.Team=='Egypt') & (athletesDF.Medal.notna())]
athletesEgyptDF_Sorted = athletesEgyptDF.sort_values(by=['Year','Medal','Sport'])
athletesEgyptDF_Sorted2 = athletesEgyptDF_Sorted[['Year','Medal','Sport']]
athletesEgyptDF_Gold = athletesEgyptDF_Sorted2.value_counts()
athletesEgyptDF_Gold
# Out:
# Year  Medal   Sport
# 2016  Bronze  Weightlifting    2
# 2004  Bronze  Boxing           2
# 1936  Bronze  Weightlifting    2
#       Gold    Weightlifting    2
# 1948  Gold    Weightlifting    2
# 2016  Bronze  Taekwondo        1
# 2012  Silver  Wrestling        1
#               Fencing          1
# 2008  Bronze  Judo             1
# 2004  Silver  Boxing           1
#       Gold    Wrestling        1
#       Bronze  Taekwondo        1
# 1928  Bronze  Diving           1
# 1984  Silver  Judo             1
# 1928  Gold    Weightlifting    1
# 1948  Silver  Wrestling        1
#               Weightlifting    1
#       Bronze  Wrestling        1
# 1936  Silver  Weightlifting    1
# 1928  Silver  Diving           1
#       Gold    Wrestling        1
# 1952  Bronze  Wrestling        1
# Name: count, dtype: int64
