# %%
import pandas as pd
olympicsDF = pd.read_csv(r'C:\Users\samwa\OneDrive - Metrolinx\!P\LnkdN\AI & ML\pandas Essential Training\ExerciseFiles\data\olympics.csv',skiprows=4)
olympicsDF.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
Chn2008DF = olympicsDF[(olympicsDF.Edition==2008) & (olympicsDF.NOC=='CHN')]
Chn2008MdlsDF = Chn2008DF.Medal
#Chn2008MdlsDF.value_counts()
Chn2008DF.Medal.value_counts()
# Out:
# Medal
# Gold      74
# Bronze    57
# Silver    53
# Name: count, dtype: int64

# %%
Chn2008DF.Gender.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
import matplotlib as plt
# %matplotlib inline

# %%
Chn2008MdlsDF.value_counts().plot(kind='bar',colormap='Pastel1');

# %%
import seaborn as sns

# %%
sns.countplot(x='Medal',data=Chn2008DF);

# %%
sns.countplot(x='Gender',data=Chn2008DF);

# %%
sns.countplot(x='Gender',data=Chn2008DF,palette='bwr');

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.countplot(x='Medal',data=Chn2008DF,hue='Gender');

# %%
#menMedalsDF = Chn2008DF[Chn2008DF.Gender=='Men']
#menMedalsDF.Medal.value_counts().plot(kind='bar')

#womenMedalsDF = olympicsDF[olympicsDF.Gender=='Women']
#womenMedalsDF.Medal.value_counts().plot(kind='bar')

# %%
sns.countplot(x='Medal',data=Chn2008DF,hue='Gender',palette='bwr',order=['Gold','Silver','Bronze']);
