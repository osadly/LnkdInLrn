# %%
import pandas as pd

# %%
FN_LN_SIN_GNDR_DoB = pd.read_csv(r'C:\Users\samwa\OneDrive - Metrolinx\!P\LnkdN\AI & ML\pandas Essential Training\DATA\OMERS_VS_HCM\2_FN_LN_SIN_GNDR_DoB.csv')

# %%
FN_LN_SIN_GNDR_DoB
# Out:
#       Employee ID     Last Name First Name Middle Name  \
# 0           313.0   De Gasperin      Linda         NaN
# 1           339.0      McKinnon    Roselea         NaN
# 2           808.0       O'Leary      James           T
# 3           891.0          Reid      Irene         NaN
# 4           974.0        Taylor    Suzanne           E
# ...           ...           ...        ...         ...
# 6613      75900.0       Donahoe     Robert     Anthony
# 6614      75924.0     Elimimian      Henry         NaN
# 6615      75926.0  Van Schubert      Kevin        John
# 6616      75964.0       Murtuza     Humzah         NaN
# 6617          NaN           NaN        NaN         NaN
#
#      Social Insurance Number (SIN)  Department ID Gender Date of Birth  \
# 0                      469 498 927            NaN      F   28-Jan-1960
# 1                      114 520 950            NaN      F    2-May-1956
# 2                      457 743 946            NaN      M    9-Feb-1956
# ...

# %%
FN_LN_SIN_GNDR_DoB.head()
# Out:
#    Employee ID    Last Name First Name Middle Name  \
# 0        313.0  De Gasperin      Linda         NaN
# 1        339.0     McKinnon    Roselea         NaN
# 2        808.0      O'Leary      James           T
# 3        891.0         Reid      Irene         NaN
# 4        974.0       Taylor    Suzanne           E
#
#   Social Insurance Number (SIN)  Department ID Gender Date of Birth  \
# 0                   469 498 927            NaN      F   28-Jan-1960
# 1                   114 520 950            NaN      F    2-May-1956
# 2                   457 743 946            NaN      M    9-Feb-1956
# 3                   475 564 076            NaN      F    8-Oct-1965
# 4                   467 922 373            NaN      F   18-Jan-1961
#
#   Has the employee signed Form 132: Authorization for Disclosure of Personal Information?    \
# 0                                                 No
# 1                                                 No
# ...

# %%
FN_LN_SIN_GNDR_DoB.shape
# Out:
# (6618, 244)

# %%
FN_LN_SIN_GNDR_DoB.shape[0]
# Out:
# 6618

# %%
FN_LN_SIN_GNDR_DoB.shape[1]
# Out:
# 244

# %%
FN_LN_SIN_GNDR_DoB.head(10)
# Out:
#    Employee ID    Last Name First Name Middle Name  \
# 0        313.0  De Gasperin      Linda         NaN
# 1        339.0     McKinnon    Roselea         NaN
# 2        808.0      O'Leary      James           T
# 3        891.0         Reid      Irene         NaN
# 4        974.0       Taylor    Suzanne           E
# 5       1026.0       Mantua       Joao         NaN
# 6       1061.0      Di Maio     Emilio         NaN
# 7       1189.0     DeLellis      Maria         NaN
# 8       1236.0        Buttu      Nancy         NaN
# 9       1248.0      Johnson      Peter         NaN
#
#   Social Insurance Number (SIN)  Department ID Gender Date of Birth  \
# 0                   469 498 927            NaN      F   28-Jan-1960
# 1                   114 520 950            NaN      F    2-May-1956
# 2                   457 743 946            NaN      M    9-Feb-1956
# 3                   475 564 076            NaN      F    8-Oct-1965
# ...

# %%
FN_LN_SIN_GNDR_DoB.tail(10)
# Out:
#       Employee ID     Last Name First Name Middle Name  \
# 6608      75849.0      Kartzali   Nicholas       James
# 6609      75852.0           Ulm    Pauline         A J
# 6610      75853.0        Bandoo     Adeeta       Marie
# 6611      75854.0           Lee    Michael       Chung
# 6612      75880.0       O'Leary      Ethan        Wade
# 6613      75900.0       Donahoe     Robert     Anthony
# 6614      75924.0     Elimimian      Henry         NaN
# 6615      75926.0  Van Schubert      Kevin        John
# 6616      75964.0       Murtuza     Humzah         NaN
# 6617          NaN           NaN        NaN         NaN
#
#      Social Insurance Number (SIN)  Department ID Gender Date of Birth  \
# 6608                   514 437 938            NaN      M    3-Mar-1981
# 6609                   150 891 125            NaN      F    3-Mar-1988
# 6610                   565 238 714            NaN      F   22-Apr-1983
# 6611                   522 284 124            NaN      M   18-Jun-1990
# ...

# %%
FN_LN_SIN_GNDR_DoB.head().shape
# Out:
# (5, 244)

# %%
FN_LN_SIN_GNDR_DoB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6618 entries, 0 to 6617
# Columns: 244 entries, Employee ID to Unnamed: 243
# dtypes: float64(227), object(17)
# memory usage: 12.3+ MB

# %%
FN_LN_SIN_GNDR_DoB.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6618 entries, 0 to 6617
# Data columns (total 244 columns):
#  #    Column                                                                                     Non-Null Count  Dtype
# ---   ------                                                                                     --------------  -----
#  0    Employee ID                                                                                6617 non-null   float64
#  1    Last Name                                                                                  6617 non-null   object
#  2    First Name                                                                                 6617 non-null   object
#  3    Middle Name                                                                                2128 non-null   object
#  4    Social Insurance Number (SIN)                                                              6615 non-null   object
# ...
