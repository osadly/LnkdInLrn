# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
olympicsDF=pd.read_csv(r'.\ExerciseFiles\data\olympics.csv',skiprows=4)
olympicsDF.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
olympicsDF.groupby('Edition')

# %%
type(olympicsDF.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(olympicsDF.groupby('Edition'))
# Out:
# [(1896,
#          City  Edition          Sport       Discipline  \
#   0    Athens     1896       Aquatics         Swimming
#   1    Athens     1896       Aquatics         Swimming
#   2    Athens     1896       Aquatics         Swimming
#   3    Athens     1896       Aquatics         Swimming
#   4    Athens     1896       Aquatics         Swimming
#   ..      ...      ...            ...              ...
#   146  Athens     1896  Weightlifting    Weightlifting
#   147  Athens     1896  Weightlifting    Weightlifting
#   148  Athens     1896      Wrestling  Wrestling Gre-R
#   149  Athens     1896      Wrestling  Wrestling Gre-R
#   150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                         Athlete  NOC Gender                        Event  \
#   0               HAJOS, Alfred  HUN    Men               100m freestyle
#   1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for group_key, group_value in olympicsDF.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#        City  Edition          Sport       Discipline  \
# 0    Athens     1896       Aquatics         Swimming
# 1    Athens     1896       Aquatics         Swimming
# 2    Athens     1896       Aquatics         Swimming
# 3    Athens     1896       Aquatics         Swimming
# 4    Athens     1896       Aquatics         Swimming
# ..      ...      ...            ...              ...
# 146  Athens     1896  Weightlifting    Weightlifting
# 147  Athens     1896  Weightlifting    Weightlifting
# 148  Athens     1896      Wrestling  Wrestling Gre-R
# 149  Athens     1896      Wrestling  Wrestling Gre-R
# 150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# 2           DRIVAS, Dimitrios  GRE    Men   100m freestyle for sailors
# ...

# %%
for group_key, group_value in olympicsDF.groupby('Edition'):
    print(group_key)
# Out:
# 1896
# 1900
# 1904
# 1908
# 1912
# 1920
# 1924
# 1928
# 1932
# 1936
# 1948
# 1952
# 1956
# 1960
# 1964
# 1968
# 1972
# 1976
# 1980
# 1984
# 1988
# 1992
# 1996
# 2000
# 2004
# 2008

# %%
print("type(group_key) is: ", type(group_key), " & type(group_value) is: ",type(group_value))
# Out:
# type(group_key) is:  <class 'int'>  & type(group_value) is:  <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
olympicsDF.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
olympicsDF.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                        City                         Sport                 \
#                         min      max count            min            max
# Edition NOC Medal
# 1896    AUS Gold     Athens   Athens     2      Athletics      Athletics
#         AUT Bronze   Athens   Athens     2        Cycling        Cycling
#             Gold     Athens   Athens     2       Aquatics        Cycling
#             Silver   Athens   Athens     1       Aquatics       Aquatics
#         DEN Bronze   Athens   Athens     3        Fencing       Shooting
# ...                     ...      ...   ...            ...            ...
# 2008    UZB Silver  Beijing  Beijing     2           Judo      Wrestling
#         VEN Bronze  Beijing  Beijing     1      Taekwondo      Taekwondo
#         VIE Silver  Beijing  Beijing     1  Weightlifting  Weightlifting
#         ZIM Gold    Beijing  Beijing     1       Aquatics       Aquatics
#             Silver  Beijing  Beijing     3       Aquatics       Aquatics
#
# ...

# %%
olympicsDF.groupby(['Edition','NOC','Medal']).agg('count')
# Out:
#                     City  Sport  Discipline  Athlete  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold       2      2           2        2       2      2
#         AUT Bronze     2      2           2        2       2      2
#             Gold       2      2           2        2       2      2
#             Silver     1      1           1        1       1      1
#         DEN Bronze     3      3           3        3       3      3
# ...                  ...    ...         ...      ...     ...    ...
# 2008    UZB Silver     2      2           2        2       2      2
#         VEN Bronze     1      1           1        1       1      1
#         VIE Silver     1      1           1        1       1      1
#         ZIM Gold       1      1           1        1       1      1
#             Silver     3      3           3        3       3      3
#
#                     Event_gender
# Edition NOC Medal
# 1896    AUS Gold               2
#         AUT Bronze             2
# ...

# %%
olympicsDF.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
olympicsDF.groupby(['Edition','NOC','Medal']).agg({'Edition': ['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
olympicsDF[olympicsDF.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
olympicsDF[olympicsDF.Athlete=='LEWIS, Carl'].groupby('Medal').agg({'Edition':['min','max','count']})
# Out:
#        Edition
#            min   max count
# Medal
# Gold      1984  1996     9
# Silver    1988  1988     1

# %%
olympicsDF[olympicsDF.NOC=='EGY'].groupby('NOC').agg({'Edition':['min','max','count']})
# Out:
#     Edition
#         min   max count
# NOC
# EGY    1928  2008    24

# %%
olympicsDF[olympicsDF.NOC=='EGY'].groupby('Medal').agg({'Edition':['min','max','count']})
# Out:
#        Edition
#            min   max count
# Medal
# Bronze    1928  2008    10
# Gold      1928  2004     7
# Silver    1928  2004     7

# %%
olympicsDF[olympicsDF.NOC=='EGY'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#                             Edition
#                                 min   max count
# Athlete
# ALY, Mohamed                   2004  2004     1
# BAYOUMI, Tamer                 2004  2004     1
# EL GINDY, Abdel Moneim         1960  1960     1
# EL TOUNY, Khadr El Sayed       1936  1936     1
# ELSAYED, Mohamed               2004  2004     1
# FAYAD, Mahmoud                 1948  1948     1
# GABER IBRAHIM, Karam           2004  2004     1
# HAMOUDA, Attia Mohamed         1948  1948     1
# HASSAN ALI, Mahmoud            1948  1948     1
# ISMAIL, Ahmed                  2004  2004     1
# MESBAH, Anwar Mohamed Ahmed    1936  1936     1
# MESBAH, Hesham                 2008  2008     1
# MOUSTAPHA, Ibrahim             1928  1928     1
# NOSSEIR, El Sayed Mohamed      1928  1928     1
# ORABI, Ibrahim                 1948  1948     1
# RASHED, Abdel Aal Ahmed        1952  1952     1
# RASHWAN, Mohamed               1984  1984     1
# SAYED, Osman                   1960  1960     1
# ...

# %%
df = olympicsDF[olympicsDF.NOC=='EGY'].groupby('Athlete').agg({'Edition':['min','max','count']})
df.head()
# Out:
#                          Edition
#                              min   max count
# Athlete
# ALY, Mohamed                2004  2004     1
# BAYOUMI, Tamer              2004  2004     1
# EL GINDY, Abdel Moneim      1960  1960     1
# EL TOUNY, Khadr El Sayed    1936  1936     1
# ELSAYED, Mohamed            2004  2004     1

# %%
df.columns
# Out:
# MultiIndex([('Edition',   'min'),
#             ('Edition',   'max'),
#             ('Edition', 'count')],
#            )

# %%
df.sort_values([('Edition', 'min')])
# Out:
#                             Edition
#                                 min   max count
# Athlete
# SIMAIKA, Farid                 1928  1928     2
# NOSSEIR, El Sayed Mohamed      1928  1928     1
# MOUSTAPHA, Ibrahim             1928  1928     1
# MESBAH, Anwar Mohamed Ahmed    1936  1936     1
# SHAMS, Ibrahim Hassanein       1936  1948     2
# SOLIMAN, Saleh Mohamed         1936  1936     1
# WASIF, Ibrahim                 1936  1936     1
# EL TOUNY, Khadr El Sayed       1936  1936     1
# HAMOUDA, Attia Mohamed         1948  1948     1
# HASSAN ALI, Mahmoud            1948  1948     1
# FAYAD, Mahmoud                 1948  1948     1
# ORABI, Ibrahim                 1948  1948     1
# RASHED, Abdel Aal Ahmed        1952  1952     1
# SAYED, Osman                   1960  1960     1
# EL GINDY, Abdel Moneim         1960  1960     1
# RASHWAN, Mohamed               1984  1984     1
# ISMAIL, Ahmed                  2004  2004     1
# ELSAYED, Mohamed               2004  2004     1
# ...

# %%
dfgb = olympicsDF.groupby(['Edition','NOC','Medal']).agg({'Edition': ['count']})
dfgb
# Out:
#                    Edition
#                      count
# Edition NOC Medal
# 1896    AUS Gold         2
#         AUT Bronze       2
#             Gold         2
#             Silver       1
#         DEN Bronze       3
# ...                    ...
# 2008    UZB Silver       2
#         VEN Bronze       1
#         VIE Silver       1
#         ZIM Gold         1
#             Silver       3
#
# [2356 rows x 1 columns]
