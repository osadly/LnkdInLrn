# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
olympicsDF = pd.read_csv(r'.\ExerciseFiles\data\olympics.csv',skiprows=4)
olympicsDF.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#olympicsDF['Edition'].value_counts().sort_values(key=lambda x:x)
olympicsDF.reset_index(inplace=True)
olympicsDF
# Out:
#        index     City  Edition      Sport       Discipline  \
# 0          0   Athens     1896   Aquatics         Swimming
# 1          1   Athens     1896   Aquatics         Swimming
# 2          2   Athens     1896   Aquatics         Swimming
# 3          3   Athens     1896   Aquatics         Swimming
# 4          4   Athens     1896   Aquatics         Swimming
# ...      ...      ...      ...        ...              ...
# 29211  29211  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213  29213  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214  29214  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215  29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
#                     Athlete  NOC Gender                       Event  \
# 0             HAJOS, Alfred  HUN    Men              100m freestyle
# 1          HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %%
olympicsDF_MedalIndex = olympicsDF.set_index('Medal')
olympicsDF_MedalIndex
# Out:
#         index     City  Edition      Sport       Discipline  \
# Medal
# Gold        0   Athens     1896   Aquatics         Swimming
# Silver      1   Athens     1896   Aquatics         Swimming
# Bronze      2   Athens     1896   Aquatics         Swimming
# Gold        3   Athens     1896   Aquatics         Swimming
# Silver      4   Athens     1896   Aquatics         Swimming
# ...       ...      ...      ...        ...              ...
# Silver  29211  Beijing     2008  Wrestling  Wrestling Gre-R
# Bronze  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# Bronze  29213  Beijing     2008  Wrestling  Wrestling Gre-R
# Gold    29214  Beijing     2008  Wrestling  Wrestling Gre-R
# Silver  29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
#                      Athlete  NOC Gender                       Event  \
# Medal
# Gold           HAJOS, Alfred  HUN    Men              100m freestyle
# Silver      HERSCHMANN, Otto  AUT    Men              100m freestyle
# ...

# %%
olympicsDF_MedalIndex['Edition'].value_counts().sort_index()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# Name: count, dtype: int64

# %%
olympicsDF_MedalIndex['Edition'].value_counts().sort_index().plot(kind='bar');

# %%
# Solution provided in the course / as per the video :)
olympicsDF.Edition.value_counts().sort_index().plot();

# %%
olympicsDF_EditionIndex = olympicsDF.set_index('Edition')
olympicsDF_EditionIndex.head()
# Out:
#          index    City     Sport Discipline             Athlete  NOC Gender  \
# Edition
# 1896         0  Athens  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1896         1  Athens  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 1896         2  Athens  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 1896         3  Athens  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 1896         4  Athens  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                               Event Event_gender   Medal
# Edition
# 1896                 100m freestyle            M    Gold
# 1896                 100m freestyle            M  Silver
# 1896     100m freestyle for sailors            M  Bronze
# 1896     100m freestyle for sailors            M    Gold
# 1896     100m freestyle for sailors            M  Silver

# %%
olympicsDF_EditionIndex.loc[2008].NOC
# Out:
# Edition
# 2008    RUS
# 2008    AUS
# 2008    CHN
# 2008    CHN
# 2008    CHN
#        ...
# 2008    GER
# 2008    LTU
# 2008    ARM
# 2008    CUB
# 2008    RUS
# Name: NOC, Length: 2042, dtype: object

# %%
#olympicsDF2008_Index_NOC.value_counts()

# %%
# Solution provided in the course / as per the video :)

olympics2008DF = olympicsDF[olympicsDF.Edition==2008]

# print(type(olympics2008DF)) => <class 'pandas.core.frame.DataFrame'>

olympics2008_NOC_DS = olympics2008DF.NOC
# print(type(olympics2008_NOC_DS)) => <class 'pandas.core.series.Series'>
olympics2008_NOC_DS
# Out:
# 27174    RUS
# 27175    AUS
# 27176    CHN
# 27177    CHN
# 27178    CHN
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 2042, dtype: object

# %%
NOC_DF = pd.read_csv(r'.\ExerciseFiles\data\Summer Olympic medallists 1896 to 2008 - IOC COUNTRY CODES.csv')
NOC_DF.head()
# Out:
#            Country Int Olympic Committee code ISO code        Country.1
# 0      Afghanistan                        AFG       AF      Afghanistan
# 1          Albania                        ALB       AL          Albania
# 2          Algeria                        ALG       DZ          Algeria
# 3  American Samoa*                        ASA       AS  American Samoa*
# 4          Andorra                        AND       AD          Andorra

# %%
# validate that both columns: Country & Country.1 are identical - no single difference found
NOC_DF[NOC_DF['Country'] != NOC_DF['Country.1']]
# Out:
# Empty DataFrame
# Columns: [Country, Int Olympic Committee code, ISO code, Country.1]
# Index: []

# %%
NOC_DF.set_index('Int Olympic Committee code',inplace=True)
NOC_DF.head()
# Out:
#                                     Country ISO code        Country.1
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra

# %%
medals2008DS = olympics2008_NOC_DS.value_counts()

#medals2008DS.sort_values(ascending=False)

# type(medals2008DS) => pandas.core.series.Series

medals2008DS.head()
# Out:
# NOC
# USA    315
# CHN    184
# AUS    149
# RUS    143
# GER    101
# Name: count, dtype: int64

# %%
NOC_DF['medals2008DS']=medals2008DS
NOC_DF
# Out:
#                                     Country ISO code        Country.1  \
# Int Olympic Committee code
# AFG                             Afghanistan       AF      Afghanistan
# ALB                                 Albania       AL          Albania
# ALG                                 Algeria       DZ          Algeria
# ASA                         American Samoa*       AS  American Samoa*
# AND                                 Andorra       AD          Andorra
# ...                                     ...      ...              ...
# VIE                                 Vietnam       VN          Vietnam
# ISV                         Virgin Islands*       VI  Virgin Islands*
# YEM                                   Yemen       YE            Yemen
# ZAM                                  Zambia       ZM           Zambia
# ZIM                                Zimbabwe       ZW         Zimbabwe
#
#                             medals2008DS
# Int Olympic Committee code
# ...

# %%
NOC_DF[NOC_DF.medals2008DS.isnull()]
# Out:
#                                         Country ISO code            Country.1  \
# Int Olympic Committee code
# ALB                                     Albania       AL              Albania
# ASA                             American Samoa*       AS      American Samoa*
# AND                                     Andorra       AD              Andorra
# ANG                                      Angola       AO               Angola
# ANT                         Antigua and Barbuda       AG  Antigua and Barbuda
# ...                                         ...      ...                  ...
# URU                                     Uruguay       UY              Uruguay
# VAN                                     Vanuatu       VU              Vanuatu
# ISV                             Virgin Islands*       VI      Virgin Islands*
# YEM                                       Yemen       YE                Yemen
# ZAM                                      Zambia       ZM               Zambia
#
# ...
